# %%
pip install requests beautifulsoup4
# Out:
# Requirement already satisfied: requests in c:\users\fatimah\anaconda3\lib\site-packages (2.31.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\fatimah\anaconda3\lib\site-packages (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\fatimah\anaconda3\lib\site-packages (from requests) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\fatimah\anaconda3\lib\site-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\fatimah\anaconda3\lib\site-packages (from requests) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\fatimah\anaconda3\lib\site-packages (from requests) (2023.11.17)
# Requirement already satisfied: soupsieve>1.2 in c:\users\fatimah\anaconda3\lib\site-packages (from beautifulsoup4) (2.4)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Importing Libraries

# %%
import requests
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
class crypto(object):
    def scrape_data(self):
        pass
    def clean_data(self):
        pass
    def handle_missing_values(self):
        pass
    def scrape_crypto_prices(crypto_symbol):
        pass
    def calculate_log_returns(self):
        pass
    def save_to_csv(self):
        pass
    def display_data(self):
        pass
    def perform_analysis(self):
        pass
    def create_visualizations(self):
        pass
    def plot_historical_prices(self):
        pass
    def plot_mean_returns(self):
        pass
class bitcoin(crypto):
    def __init__(self):
        self.data = self.scrape_data()
    def scrape_data(self):
        url = "https://data.messari.io/api/v1/assets/bitcoin/metrics/price/time-series"
        try:
            response = requests.get(url, verify=True)
            response.raise_for_status()
            data = response.json()['data']['values']
            return pd.DataFrame(data)
        except requests.exceptions.RequestException as e:
            print("Error fetching data for bitcoin: {}".format(e))
            return None
    def clean_data(self):
        self.data.columns = ['time', 'opening_price', 'closing_price', 'high', 'low', 'volume']
        self.data = self.data.dropna()
    def handle_missing_values(self):
        for column in self.data.columns:
            self.data[column] = self.data[column].fillna(self.data[column].mean())
    def calculate_log_returns(self):
        price_columns = ['opening_price', 'closing_price', 'high', 'low']
        for col in price_columns:
            self.data[f'{col}_log_return'] = np.log(self.data[col] / self.data[col].shift(1))

    def save_to_csv(self):
        if self.data is not None:
            csv_filename = "bitcoin_data.csv"
            self.data.to_csv(csv_filename, index=False)
            print("\nData for bitcoin saved to {}".format(csv_filename))
        else:
            print("Failed to save data for bitcoin")

    def display_data(self):
        print("\nData for bitcoin After Handling Missing Values and Calculating Log Returns:")
        print(self.data.head())

    def perform_analysis(self):
        print("\nAnalysis for bitcoin:")
        for col in ['opening_price', 'closing_price', 'high', 'low']:
            mean_return = self.data[col].mean()
            median_return = self.data[col].median()
            std_dev_return = self.data[col].std()

            print("\nAnalysis for {}:".format(col))
            print("Mean: ", mean_return)
            print("Median: ", median_return)
            print("Standard Deviation: ", std_dev_return)

            max_return_date = self.data.loc[self.data[col].idxmax(), 'time']
            max_return_value = self.data[col].max()

            print("\nDate with the Highest Return for {}:".format(col))
            print("Date: {}".format(max_return_date))
            print("Highest Return Value: {}".format(max_return_value))

    def create_visualizations(self):
        self.plot_historical_prices()
        self.plot_mean_returns()
    def plot_historical_prices(self):
        plt.figure(figsize=(9, 6))
        plt.plot(self.data['time'], self.data['closing_price'], label='Closing Price', color='green', marker='o')
        plt.title("Historical Prices of bitcoin")
        plt.xlabel("Date")
        plt.ylabel("Closing Price")
        plt.grid(True)
        plt.savefig("bitcoin_historical_prices.png")
        plt.show()
    def plot_mean_returns(self):
        price_columns = ['opening_price', 'closing_price', 'high', 'low']
        mean_returns = self.data[[col for col in price_columns]].mean()

        plt.figure(figsize=(8, 5))
        mean_returns.plot(kind='bar', color=['yellow', 'indigo', 'beige', 'pink'])
        plt.title("Mean Returns of bitcoin")
        plt.xlabel("Price Type")
        plt.ylabel("Mean Return")
        plt.savefig("bitcoin_mean_returns.png")
        plt.show()
class xrp(crypto):
    def __init__(self):
        self.data = self.scrape_data()
    def scrape_data(self):
        url = "https://data.messari.io/api/v1/assets/xrp/metrics/price/time-series"
        try:
            response = requests.get(url, verify=True)
            response.raise_for_status()
            data = response.json()['data']['values']
            return pd.DataFrame(data)
        except requests.exceptions.RequestException as e:
            print("Error fetching data for xrp: {}".format(e))
            return None
    def clean_data(self):
        self.data.columns = ['time', 'opening_price', 'closing_price', 'high', 'low', 'volume']
        self.data = self.data.dropna()
    def handle_missing_values(self):
        for column in self.data.columns:
            self.data[column] = self.data[column].fillna(self.data[column].mean())
    def calculate_log_returns(self):
        price_columns = ['opening_price', 'closing_price', 'high', 'low']
        for col in price_columns:
            self.data[f'{col}_log_return'] = np.log(self.data[col] / self.data[col].shift(1))

    def save_to_csv(self):
        if self.data is not None:
            csv_filename = "xrp_data.csv"
            self.data.to_csv(csv_filename, index=False)
            print("\nData for xrp saved to {}".format(csv_filename))
        else:
            print("Failed to save data for xrp")

    def display_data(self):
        print("\nData for xrp After Handling Missing Values and Calculating Log Returns:")
        print(self.data.head())

    def perform_analysis(self):
        print("\nAnalysis for xrp:")
        for col in ['opening_price', 'closing_price', 'high', 'low']:
            mean_return = self.data[col].mean()
            median_return = self.data[col].median()
            std_dev_return = self.data[col].std()

            print("\nAnalysis for {}:".format(col))
            print("Mean: ", mean_return)
            print("Median: ", median_return)
            print("Standard Deviation: ", std_dev_return)

            max_return_date = self.data.loc[self.data[col].idxmax(), 'time']
            max_return_value = self.data[col].max()

            print("\nDate with the Highest Return for {}:".format(col))
            print("Date: {}".format(max_return_date))
            print("Highest Return Value: {}".format(max_return_value))

    def create_visualizations(self):
        self.plot_historical_prices()
        self.plot_mean_returns()
    def plot_historical_prices(self):
        plt.figure(figsize=(9, 6))
        plt.plot(self.data['time'], self.data['closing_price'], label='Closing Price', color='green', marker='o')
        plt.title("Historical Prices of xrp")
        plt.xlabel("Date")
        plt.ylabel("Closing Price")
        plt.grid(True)
        plt.savefig("xrp_historical_prices.png")
        plt.show()
    def plot_mean_returns(self):
        price_columns = ['opening_price', 'closing_price', 'high', 'low']
        mean_returns = self.data[[col for col in price_columns]].mean()

        plt.figure(figsize=(8, 5))
        mean_returns.plot(kind='bar', color=['yellow', 'indigo', 'beige', 'pink'])
        plt.title("Mean Returns of xrp")
        plt.xlabel("Price Type")
        plt.ylabel("Mean Return")
        plt.savefig("xrp_mean_returns.png")
        plt.show()
class ethereum(crypto):
    def __init__(self):
        self.data = self.scrape_data()
    def scrape_data(self):
        url = "https://data.messari.io/api/v1/assets/ethereum/metrics/price/time-series"
        try:
            response = requests.get(url, verify=True)
            response.raise_for_status()
            data = response.json()['data']['values']
            return pd.DataFrame(data)
        except requests.exceptions.RequestException as e:
            print("Error fetching data for ethereum: {}".format( e))
            return None
    def clean_data(self):
        self.data.columns = ['time', 'opening_price', 'closing_price', 'high', 'low', 'volume']
        self.data = self.data.dropna()
    def handle_missing_values(self):
        for column in self.data.columns:
            self.data[column] = self.data[column].fillna(self.data[column].mean())
    def calculate_log_returns(self):
        price_columns = ['opening_price', 'closing_price', 'high', 'low']
        for col in price_columns:
            self.data[f'{col}_log_return'] = np.log(self.data[col] / self.data[col].shift(1))

    def save_to_csv(self):
        if self.data is not None:
            csv_filename = "ethereum_data.csv"
            self.data.to_csv(csv_filename, index=False)
            print("\nData for ethereum saved to {}".format(csv_filename))
        else:
            print("Failed to save data for ethereum")

    def display_data(self):
        print("\nData for ethereum After Handling Missing Values and Calculating Log Returns:")
        print(self.data.head())

    def perform_analysis(self):
        print("\nAnalysis for ethereum:")
        for col in ['opening_price', 'closing_price', 'high', 'low']:
            mean_return = self.data[col].mean()
            median_return = self.data[col].median()
            std_dev_return = self.data[col].std()

            print("\nAnalysis for {}:".format(col))
            print("Mean: ", mean_return)
            print("Median: ", median_return)
            print("Standard Deviation: ", std_dev_return)

            max_return_date = self.data.loc[self.data[col].idxmax(), 'time']
            max_return_value = self.data[col].max()

            print("\nDate with the Highest Return for {}:".format(col))
            print("Date: {}".format(max_return_date))
            print("Highest Return Value: {}".format(max_return_value))

    def create_visualizations(self):
        self.plot_historical_prices()
        self.plot_mean_returns()
    def plot_historical_prices(self):
        plt.figure(figsize=(9, 6))
        plt.plot(self.data['time'], self.data['closing_price'], label='Closing Price', color='green', marker='o')
        plt.title("Historical Prices of ethereum")
        plt.xlabel("Date")
        plt.ylabel("Closing Price")
        plt.grid(True)
        plt.savefig("ethereum_historical_prices.png")
        plt.show()
    def plot_mean_returns(self):
        price_columns = ['opening_price', 'closing_price', 'high', 'low']
        mean_returns = self.data[[col for col in price_columns]].mean()

        plt.figure(figsize=(8, 5))
        mean_returns.plot(kind='bar', color=['yellow', 'indigo', 'beige', 'pink'])
        plt.title("Mean Returns of ethereum")
        plt.xlabel("Price Type")
        plt.ylabel("Mean Return")
        plt.savefig("ethereum_mean_returns.png")
        plt.show()

# %%
b_obj=bitcoin()
b_obj.clean_data()
b_obj.handle_missing_values()
b_obj.display_data()
b_obj.perform_analysis()
b_obj.plot_historical_prices()
b_obj.calculate_log_returns()
b_obj.plot_mean_returns()
b_obj.create_visualizations()
b_obj.save_to_csv()
# Out:
# Data for bitcoin After Handling Missing Values and Calculating Log Returns:
#             time  opening_price  closing_price          high           low  \
# 0  1700866800000   37713.281442   37748.987900  37614.059073  37748.644831
# 1  1700870400000   37737.266699   37796.176338  37702.341755  37748.083010
# 2  1700874000000   37747.763222   37834.692331  37741.731712  37813.733586
# 3  1700877600000   37809.417312   37842.224277  37727.176234  37839.000446
# 4  1700881200000   37835.276064   37866.455489  37790.519313  37826.319495
#
#          volume
# 0  2.369032e+08
# 1  1.840661e+08
# 2  1.453659e+08
# 3  1.502101e+08
# 4  1.825796e+08
#
# Analysis for bitcoin:
#
# Analysis for opening_price:
# Mean:  38592.68258153407
# Median:  37954.18137125244
# Standard Deviation:  1444.2122358526801
#
# Date with the Highest Return for opening_price:
# Date: 1701727200000
# Highest Return Value: 42033.704541466264
#
# Analysis for closing_price:
# Mean:  38688.82681526279
# Median:  38041.18640172339
# Standard Deviation:  1469.0588586840304
#
# Date with the Highest Return for closing_price:
# Date: 1701727200000
# Highest Return Value: 42377.924076183626
#
# Analysis for high:
# Mean:  38509.452447421194
# Median:  37850.87859792735
# Standard Deviation:  1432.277268867621
#
# Date with the Highest Return for high:
# Date: 1701727200000
# Highest Return Value: 41870.07495179669
#
# Analysis for low:
# Mean:  38609.05405739768
# Median:  37957.905732787505
# Standard Deviation:  1458.1249542322375
#
# Date with the Highest Return for low:
# Date: 1701723600000
# Highest Return Value: 42033.99329966577
# Data for bitcoin saved to bitcoin_data.csv

# %%
e_obj=ethereum()
e_obj.clean_data()
e_obj.handle_missing_values()
e_obj.display_data()
e_obj.perform_analysis()
e_obj.plot_historical_prices()
e_obj.calculate_log_returns()
e_obj.plot_mean_returns()
e_obj.create_visualizations()
e_obj.save_to_csv()
# Out:
# Data for ethereum After Handling Missing Values and Calculating Log Returns:
#             time  opening_price  closing_price         high          low  \
# 0  1700866800000    2075.684110    2082.416772  2069.325249  2082.373630
# 1  1700870400000    2082.103033    2085.894210  2074.766610  2076.276981
# 2  1700874000000    2076.238912    2087.941290  2076.238912  2087.904482
# 3  1700877600000    2087.754837    2089.367340  2080.030168  2087.837988
# 4  1700881200000    2087.782992    2091.261074  2085.930700  2088.492412
#
#          volume
# 0  1.319777e+08
# 1  1.344720e+08
# 2  1.051580e+08
# 3  1.024613e+08
# 4  9.234202e+07
#
# Analysis for ethereum:
#
# Analysis for opening_price:
# Mean:  2097.943517663249
# Median:  2083.2598612477163
# Standard Deviation:  68.67486785352777
#
# Date with the Highest Return for opening_price:
# Date: 1701687600000
# Highest Return Value: 2261.022765793016
#
# Analysis for closing_price:
# Mean:  2104.0323831897185
# Median:  2087.5101105034755
# Standard Deviation:  69.67166704614094
#
# Date with the Highest Return for closing_price:
# Date: 1701684000000
# Highest Return Value: 2272.1034466392744
#
# Analysis for high:
# Mean:  2092.0810769166424
# Median:  2077.5107847754007
# Standard Deviation:  67.86076499842699
#
# Date with the Highest Return for high:
# Date: 1701680400000
# Highest Return Value: 2246.6549449604595
#
# Analysis for low:
# Mean:  2098.467248726747
# Median:  2083.761323130685
# Standard Deviation:  68.97560898399233
#
# Date with the Highest Return for low:
# Date: 1701684000000
# Highest Return Value: 2260.653284620811
# Data for ethereum saved to ethereum_data.csv

# %%
r_obj=xrp()
r_obj.clean_data()
r_obj.handle_missing_values()
r_obj.display_data()
r_obj.perform_analysis()
r_obj.plot_historical_prices()
r_obj.calculate_log_returns()
r_obj.plot_mean_returns()
r_obj.create_visualizations()
r_obj.save_to_csv()
# Out:
# Data for xrp After Handling Missing Values and Calculating Log Returns:
#             time  opening_price  closing_price      high       low  \
# 0  1700866800000       0.620729       0.622223  0.618876  0.621669
# 1  1700870400000       0.621669       0.621669  0.618929  0.619273
# 2  1700874000000       0.619356       0.621710  0.618997  0.621569
# 3  1700877600000       0.621539       0.623393  0.619379  0.622879
# 4  1700881200000       0.622768       0.623079  0.622012  0.622278
#
#          volume
# 0  1.325137e+07
# 1  1.158518e+07
# 2  1.340168e+07
# 3  1.608043e+07
# 4  1.286273e+07
#
# Analysis for xrp:
#
# Analysis for opening_price:
# Mean:  0.6143059166152212
# Median:  0.6137243256151499
# Standard Deviation:  0.008304348275200699
#
# Date with the Highest Return for opening_price:
# Date: 1701680400000
# Highest Return Value: 0.6386891280949119
#
# Analysis for closing_price:
# Mean:  0.6159365938939382
# Median:  0.6147480866335638
# Standard Deviation:  0.008620139800457125
#
# Date with the Highest Return for closing_price:
# Date: 1701676800000
# Highest Return Value: 0.6431482474878842
#
# Analysis for high:
# Mean:  0.6124592914357456
# Median:  0.6118160995588169
# Standard Deviation:  0.008232307068895883
#
# Date with the Highest Return for high:
# Date: 1701680400000
# Highest Return Value: 0.6351176531857088
#
# Analysis for low:
# Mean:  0.6142693918752588
# Median:  0.6135143247425235
# Standard Deviation:  0.008282635246587957
#
# Date with the Highest Return for low:
# Date: 1701676800000
# Highest Return Value: 0.638798244167389
# Data for xrp saved to xrp_data.csv
